# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Amartya Sengupta\OneDrive\Desktop\Kaggle-Netflix\netflix_dataset.csv")

# %%
data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s1  TV Show                                       3%
# 2         s2    Movie                                     7:19
# 3         s3    Movie                                    23:59
# 4         s4    Movie                                        9
# ...      ...      ...                                      ...
# 7783   s7783    Movie                                     Zozo
# 7784   s7784    Movie                                   Zubaan
# 7785   s7785    Movie                        Zulu Man in Japan
# 7786   s7786  TV Show                    Zumbo's Just Desserts
# 7787   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s1  TV Show     3%                NaN
# 2      s2    Movie   7:19  Jorge Michel Grau
# 3      s3    Movie  23:59       Gilbert Chan
# 4      s4    Movie      9        Shane Acker
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 4  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 1  14-Aug-20          2020  TV-MA  4 Seasons
# 2  23-Dec-16          2016  TV-MA     93 min
# 3  20-Dec-18          2011      R     78 min
# 4  16-Nov-17          2009  PG-13     80 min
#
# ...

# %%
data.tail()
# Out:
#      show_id     type                                    title     director  \
# 7783   s7783    Movie                                     Zozo  Josef Fares
# 7784   s7784    Movie                                   Zubaan  Mozez Singh
# 7785   s7785    Movie                        Zulu Man in Japan          NaN
# 7786   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7787   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7783  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7784  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7785                                            Nasty C
# 7786                         Adriano Zumbo, Rachel Khoo
# 7787                                                NaN
#
#                                                 country date_added  \
# 7783  Sweden, Czech Republic, United Kingdom, Denmar...  19-Oct-20
# ...

# %% [markdown]
# 1. Getting some basic information about the dataset

# %%
data.head() # to show top-5 records of the dataset
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s1  TV Show     3%                NaN
# 2      s2    Movie   7:19  Jorge Michel Grau
# 3      s3    Movie  23:59       Gilbert Chan
# 4      s4    Movie      9        Shane Acker
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 4  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 1  14-Aug-20          2020  TV-MA  4 Seasons
# 2  23-Dec-16          2016  TV-MA     93 min
# 3  20-Dec-18          2011      R     78 min
# 4  16-Nov-17          2009  PG-13     80 min
#
# ...

# %%
data.tail()  # to show the bottom 5 records of the dataset
# Out:
#      show_id     type                                    title     director  \
# 7783   s7783    Movie                                     Zozo  Josef Fares
# 7784   s7784    Movie                                   Zubaan  Mozez Singh
# 7785   s7785    Movie                        Zulu Man in Japan          NaN
# 7786   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7787   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7783  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7784  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7785                                            Nasty C
# 7786                         Adriano Zumbo, Rachel Khoo
# 7787                                                NaN
#
#                                                 country date_added  \
# 7783  Sweden, Czech Republic, United Kingdom, Denmar...  19-Oct-20
# ...

# %%
data.shape    # to show the No. of rows and columns
# Out:
# (7788, 12)

# %%
data.size     # to show the No. of total values(elements) in the dataset
# Out:
# 93456

# %%
data.columns   # to show each Column Name
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes     # to show each Column Name
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()     # To show indexes, columns , data-types of each columns , memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7788 entries, 0 to 7787
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7788 non-null   object
#  1   type          7788 non-null   object
#  2   title         7788 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7070 non-null   object
#  5   country       7282 non-null   object
#  6   date_added    7778 non-null   object
#  7   release_year  7788 non-null   int64
#  8   rating        7781 non-null   object
#  9   duration      7788 non-null   object
#  10  listed_in     7788 non-null   object
#  11  description   7788 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
# Task. 1. Is there any Duplicate Record in this datBaset ? if yes, then remove the duplicate records

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s1  TV Show     3%                NaN
# 2      s2    Movie   7:19  Jorge Michel Grau
# 3      s3    Movie  23:59       Gilbert Chan
# 4      s4    Movie      9        Shane Acker
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 4  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 1  14-Aug-20          2020  TV-MA  4 Seasons
# 2  23-Dec-16          2016  TV-MA     93 min
# 3  20-Dec-18          2011      R     78 min
# 4  16-Nov-17          2009  PG-13     80 min
#
# ...

# %%
data.shape
# Out:
# (7788, 12)

# %%
data[data.duplicated]   #To check row wise and detect the Duplicate rows
# Out:
#   show_id     type title director  \
# 1      s1  TV Show    3%      NaN
#
#                                                 cast country date_added  \
# 1  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
#
#    release_year rating   duration  \
# 1          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 1  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 1  In a future where the elite inhabit an island ...

# %%
data.drop_duplicates(inplace = True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.shape
# Out:
# (7787, 12)

# %% [markdown]
# Task 2 Is there any Null Value present in any column ? Show with Heat-map

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 2      s2    Movie   7:19  Jorge Michel Grau
# 3      s3    Movie  23:59       Gilbert Chan
# 4      s4    Movie      9        Shane Acker
# 5      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 4  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 5  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 2  23-Dec-16          2016  TV-MA     93 min
# 3  20-Dec-18          2011      R     78 min
# 4  16-Nov-17          2009  PG-13     80 min
# 5   1-Jan-20          2008  PG-13    123 min
#
# ...

# %%
   data.isnull()                      # To show where Null value is present
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False     False  False    False       False
# 5       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7783    False  False  False     False  False    False       False
# 7784    False  False  False     False  False    False       False
# 7785    False  False  False      True  False     True       False
# 7786    False  False  False      True  False    False       False
# 7787    False  False  False     False   True    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()                                   # To show the count of Null Values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          506
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# seaborn library (heat-map)

# %%
import seaborn as sns                           #To import seaborn library

# %% [markdown]
# sns.heatmap(data.isnull())                                           # Using heat-map to show null values count

# %% [markdown]
# # For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 2      s2    Movie   7:19  Jorge Michel Grau
# 3      s3    Movie  23:59       Gilbert Chan
# 4      s4    Movie      9        Shane Acker
# 5      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 4  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 5  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 2  23-Dec-16          2016  TV-MA     93 min
# 3  20-Dec-18          2011      R     78 min
# 4  16-Nov-17          2009  PG-13     80 min
# 5   1-Jan-20          2008  PG-13    123 min
#
# ...

# %%
data['title']
# Out:
# 0                                            3%
# 2                                          7:19
# 3                                         23:59
# 4                                             9
# 5                                            21
#                          ...
# 7783                                       Zozo
# 7784                                     Zubaan
# 7785                          Zulu Man in Japan
# 7786                      Zumbo's Just Desserts
# 7787    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: title, Length: 7787, dtype: object

# %%
data[data['title'].isin(['House of Cards'])]                 #To show all records of a particular item in any column
# Out:
#      show_id     type           title director  \
# 2833   s2833  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 2833  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      date_added  release_year rating   duration                listed_in  \
# 2833   2-Nov-18          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 2833  A ruthless politician will stop at nothing to ...

# %%
  data[data['title'].str.contains('House of Cards')]                                    # To show all records of a particular string in any column
# Out:
#      show_id     type           title director  \
# 2833   s2833  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 2833  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      date_added  release_year rating   duration                listed_in  \
# 2833   2-Nov-18          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 2833  A ruthless politician will stop at nothing to ...

# %% [markdown]
# In which year highest number of the TV shows & movies were released ? Show with Bar Graph

# %% [markdown]
# dtypes

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# To_Datetime

# %%
data['Date_N'] = pd.to_datetime(data['date_added'])
# Out:
# C:\Users\Amartya Sengupta\AppData\Local\Temp\ipykernel_17156\159192151.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date_N'] = pd.to_datetime(data['date_added'])

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 2      s2    Movie   7:19  Jorge Michel Grau
# 3      s3    Movie  23:59       Gilbert Chan
# 4      s4    Movie      9        Shane Acker
# 5      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 4  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 5  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 2  23-Dec-16          2016  TV-MA     93 min
# 3  20-Dec-18          2011      R     78 min
# 4  16-Nov-17          2009  PG-13     80 min
# 5   1-Jan-20          2008  PG-13    123 min
#
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %% [markdown]
# dt.year.value_counts

# %%
data['Date_N'].dt.year.value_counts()                                  #It counts the occurance of all individual Years in Date column.
# Out:
# Date_N
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# Bar Graph

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar',xlabel='year of release',ylabel='No of shows released')
# Out:
# <Axes: xlabel='year of release', ylabel='No of shows released'>

# %% [markdown]
# How many movies and TV shows are in this dataset? Show with Bar Graph

# %%
groupby

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby('type').type.count()                     #To group all unique items of a column and show their count
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
countplot()

# %%
#sns.countplot(data['type'])   
sns.countplot(data , x = 'type')   
#sns.displot(df, x='number_col')
                               # To show the count of all unique values of any column in the form of bar graph
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# #Show all the movies that were released in the year 2000

# %% [markdown]
# #Creating new column

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data['Year'] = data['Date_N'].dt.year                                  #To create new year column ; it will consider only year

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %% [markdown]
# Filtering

# %%
data [ (data['type'] == 'Movie') & (data['Year'] == 2020) ]
# Out:
#      show_id   type                                    title  \
# 5         s5  Movie                                       21
# 7         s7  Movie                                      122
# 15       s15  Movie                                     3022
# 28       s28  Movie                                   #Alive
# 29       s29  Movie            #AnneFrank - Parallel Stories
# ...      ...    ...                                      ...
# 7761   s7761  Movie                                Zaki Chan
# 7782   s7782  Movie                                     Zoom
# 7783   s7783  Movie                                     Zozo
# 7785   s7785  Movie                        Zulu Man in Japan
# 7787   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          director  \
# 5                  Robert Luketic
# 7                 Yasir Al Yasiri
# 15                     John Suits
# 28                         Cho Il
# 29    Sabina Fedeli, Anna Migotto
# ...

# %% [markdown]
# Show only the Titles of all TV shows that were released in India only

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data [ (data['type'] == 'TV Show') & (data['country'] == 'India') ]['show_id']
#data [ (data['type'] == 'TV Show') & (data['country'] == 'India') ]['title']
# Out:
# 87        s87
# 133      s133
# 341      s341
# 365      s365
# 534      s534
#         ...
# 6249    s6249
# 6399    s6399
# 6468    s6468
# 7293    s7293
# 7704    s7704
# Name: show_id, Length: 71, dtype: object

# %% [markdown]
# #Show Top 10 Directors, who gave the highest number of TV shows & Movies to Netflix

# %% [markdown]
# #value_counts

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data['director'].value_counts().head(15)
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Robert Rodriguez           8
# Kunle Afolayan             8
# Hakan Algül                8
# Shannon Hartman            8
# Johnnie To                 8
# Name: count, dtype: int64

# %% [markdown]
# Show all the Records where "Category is Movie and Type is comedies" or country is "United Kingdom"

# %%
data[(data['type'] == 'Movie') & (data['listed_in'] == 'Comedies') | (data['country'] == 'United Kingdom') ]
# Out:
#      show_id     type                   title          director  \
# 20       s20    Movie                     '89               NaN
# 34       s34    Movie            #realityhigh  Fernando Lebrija
# 59       s59  TV Show             100% Hotter               NaN
# 73       s73    Movie                17 Again       Burr Steers
# 83       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7669   s7669  TV Show  World War II in Colour               NaN
# 7670   s7670  TV Show  World's Busiest Cities               NaN
# 7687   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7724   s7724    Movie            You Can Tutu       James Brown
# 7739   s7739  TV Show         Young Wallander               NaN
#
#                                                    cast         country  \
# 20                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# #In how many movies/shows , Tom Cruise was cast ?

# %%
data[(data['cast'] == 'Tom Cruise')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, Year]
# Index: []

# %%
data[data['cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 data[data['cast'].str.contains('Tom Cruise')]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     131     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %%
  data_new = data.dropna()                                #Remove the null value , It drops the rows that contains all or any missing values.

# %%
data_new.shape
# Out:
# (4808, 14)

# %%
data_new.isnull
# Out:
# <bound method DataFrame.isnull of      show_id     type       title           director  \
# 2         s2    Movie        7:19  Jorge Michel Grau
# 3         s3    Movie       23:59       Gilbert Chan
# 4         s4    Movie           9        Shane Acker
# 5         s5    Movie          21     Robert Luketic
# 6         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7779   s7779    Movie  Zombieland    Ruben Fleischer
# 7781   s7781    Movie         Zoo       Shlok Sharma
# 7782   s7782    Movie        Zoom       Peter Hewitt
# 7783   s7783    Movie        Zozo        Josef Fares
# 7784   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 2     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 3     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 4     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 5     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data_new.head(2)
# Out:
#   show_id   type  title           director  \
# 2      s2  Movie   7:19  Jorge Michel Grau
# 3      s3  Movie  23:59       Gilbert Chan
#
#                                                 cast    country date_added  \
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico  23-Dec-16
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore  20-Dec-18
#
#    release_year rating duration                            listed_in  \
# 2          2016  TV-MA   93 min         Dramas, International Movies
# 3          2011      R   78 min  Horror Movies, International Movies
#
#                                          description     Date_N    Year
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 3  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 3861   s3861  Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 3861  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating duration                   listed_in  \
# 3861   1-Jan-20          1999      R  189 min  Dramas, Independent Movies
# 5071   1-Jul-19          1988      R  134 min      Classic Movies, Dramas
#
#                                             description     Date_N    Year
# 3861  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# #What are the different ratings defined by Netflix?

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data['rating'].nunique()
# Out:
# 14

# %%
data['rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #How many Movies got the 'TV-14' rating in Canada ?

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 2      s2    Movie   7:19  Jorge Michel Grau
# 3      s3    Movie  23:59       Gilbert Chan
# 4      s4    Movie      9        Shane Acker
# 5      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 4  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 5  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 2  23-Dec-16          2016  TV-MA     93 min
# 3  20-Dec-18          2011      R     78 min
# 4  16-Nov-17          2009  PG-13     80 min
# 5   1-Jan-20          2008  PG-13    123 min
#
# ...

# %%
data[(data['type'] == 'Movie') & (data['rating'] == 'TV-14') & (data['country'] == 'Canada') ].shape
# Out:
# (11, 14)

# %% [markdown]
# #How many movies got the 'R' rating, after year 2018?

# %%
data[(data['type'] == 'TV Show') & (data['rating'] == 'R') & (data['Year'] > 2018) ]
# Out:
#      show_id     type                                title           director  \
# 6436   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country date_added  \
# 6436  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN  25-Apr-19
#
#       release_year rating  duration listed_in  \
# 6436          2015      R  1 Season  TV Shows
#
#                                             description     Date_N    Year
# 6436  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# #What is the maximum duration of a Movie/Show on Netflix ?

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data['duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data['duration'].dtypes
# Out:
# dtype('O')

# %%
data[['Minutes', 'Unit']] = data['duration'].str.split(' ', expand = True)

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 2      s2    Movie   7:19  Jorge Michel Grau
# 3      s3    Movie  23:59       Gilbert Chan
# 4      s4    Movie      9        Shane Acker
# 5      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 3  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 4  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 5  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0  14-Aug-20          2020  TV-MA  4 Seasons
# 2  23-Dec-16          2016  TV-MA     93 min
# 3  20-Dec-18          2011      R     78 min
# 4  16-Nov-17          2009  PG-13     80 min
# 5   1-Jan-20          2008  PG-13    123 min
#
# ...

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# Year                   float64
# Minutes                 object
# Unit                    object
# dtype: object

# %% [markdown]
# #Which individual country has the Highest no of TV shpws?

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 2      93      min

# %%
data_tvshow = data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type title     director  \
# 0      s1  TV Show    3%          NaN
# 6      s6  TV Show    46  Serdar Akar
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 6  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey   1-Jul-17
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 6          2016  TV-MA   1 Season
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 6    International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 6  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 6       1   Season

# %%
data_tvshow.country.value_counts()
# Out:
# country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# #How we can sort the dataset by Year?

# %%
data.sort_values(by='Year')
# Out:
#      show_id     type                         title              director  \
# 1766   s1766  TV Show               Dinner for Five                   NaN
# 7114   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 3249   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3841   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3375   s3375  TV Show                      Kikoriki                   NaN
# 3493   s3493  TV Show           La Familia P. Luche                   NaN
# 3947   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    cast        country  \
# ...

# %%
data.sort_values(by='Year' , ascending = False).head(2)
# Out:
#      show_id   type             title            director  \
# 7352   s7352  Movie           Unknown  Jaume Collet-Serra
# 2014   s2014  Movie  Enter the Dragon       Robert Clouse
#
#                                                    cast  \
# 7352  Liam Neeson, Diane Kruger, January Jones, Aida...
# 2014  Bruce Lee, John Saxon, Jim Kelly, Ahna Capri, ...
#
#                                              country date_added  release_year  \
# 7352  United Kingdom, Germany, France, United States   1-Jan-21          2011
# 2014                        Hong Kong, United States   1-Jan-21          1973
#
#      rating duration                           listed_in  \
# 7352  PG-13  113 min       Action & Adventure, Thrillers
# 2014      R  103 min  Action & Adventure, Classic Movies
#
#                                             description     Date_N    Year  \
# 7352  Liam Neeson stars as a man who regains conscio... 2021-01-01  2021.0
# ...

# %% [markdown]
# #Find all the instances where :
# Category is "Movie" and Type is "Dramas"
# OR
# Category is "TV Show" and Type is "Kids TV"

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 2      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 2  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  23-Dec-16
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 2          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 2                       Dramas, International Movies
#
#                                          description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 2  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 2      93      min

# %%
data[(data['type'] == 'Movie') & (data['listed_in'] == 'Dramas') | (data['type'] == 'TV Show') & (data['listed_in'] == "Kids' TV")]
# Out:
#      show_id     type                       title        director  \
# 5         s5    Movie                          21  Robert Luketic
# 8         s8    Movie                         187  Kevin Reynolds
# 112     s112  TV Show                     44 Cats             NaN
# 171     s171    Movie                A Family Man   Mark Williams
# 233     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7667   s7667  TV Show               World of Winx  Iginio Straffi
# 7716   s7716  TV Show                        Yoko             NaN
# 7718   s7718  TV Show                         YOM             NaN
# 7757   s7757  TV Show                          Z4             NaN
# 7760   s7760  TV Show                   Zak Storm             NaN
#
#                                                    cast  \
# 5     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 8     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Amartya Sengupta\\Documents\\stockanalysis'
